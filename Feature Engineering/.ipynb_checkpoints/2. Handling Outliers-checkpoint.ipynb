# %% [markdown]
# # Handle Outliers
#
# Outliers in datasets can be determined or removed using either gaussian method or IQR method.
#
# <b>Gaussian method</b>: Outliers are points that lie beyond 3 standard deviations away from the mean
#
# <b>IQR method</b>: Outliers are points that lie beyond 1.5 interquartile range away from 25th and 75th percentile.
#
# Outlier treatment methods require proper caution, as simply removing outliers from the dataset may not always improve the performance of Machine Learning models.
#
# If proportion of outliers is large (i.e. more than 10%), these outliers require further investigation.
#
# Outliers should only be removed in the following scenarios if confirmed:
#
# 1. Data points are not related to the target population.
# 2. Data points are incorrectly recorded and could not be fixed.
#
# If uncertain about outlier treatment method, consider all possible approaches and compare the difference in results from model training for better decision making.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st
import feature_engine.outliers as feo
import feature_engine.imputation as fei
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, KNNImputer

# %%
data = pd.read_csv('owid-covid-data.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155858 entries, 0 to 155857
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    155858 non-null  object
#  1   continent                                   146487 non-null  object
#  2   location                                    155858 non-null  object
#  3   date                                        155858 non-null  object
#  4   total_cases                                 153028 non-null  float64
#  5   new_cases                                   152977 non-null  float64
#  6   new_cases_smoothed                          151826 non-null  float64
#  7   total_deaths                                135644 non-null  float64
#  8   new_deaths                                  135820 non-null  float64
#  9   new_deaths_smoothed                         135688 non-null  float64
#  10  total_cases_per_million                     152315 non-null  float64
#  11  new_cases_per_million                       152264 non-null  float64
#  12  new_cases_smoothed_per_million              151118 non-null  float64
#  13  total_deaths_per_million                    134944 non-null  float64
#  14  new_deaths_per_million                      135120 non-null  float64
#  15  new_deaths_smoothed_per_million             134988 non-null  float64
#  16  reproduction_rate                           117745 non-null  float64
#  17  icu_patients                                21232 non-null   float64
#  18  icu_patients_per_million                    21232 non-null   float64
#  19  hosp_patients                               22467 non-null   float64
#  20  hosp_patients_per_million                   22467 non-null   float64
#  21  weekly_icu_admissions                       4333 non-null    float64
#  22  weekly_icu_admissions_per_million           4333 non-null    float64
#  23  weekly_hosp_admissions                      8773 non-null    float64
#  24  weekly_hosp_admissions_per_million          8773 non-null    float64
#  25  new_tests                                   61444 non-null   float64
#  26  total_tests                                 62997 non-null   float64
#  27  total_tests_per_thousand                    62997 non-null   float64
#  28  new_tests_per_thousand                      61444 non-null   float64
#  29  new_tests_smoothed                          76720 non-null   float64
#  30  new_tests_smoothed_per_thousand             76007 non-null   float64
#  31  positive_rate                               71722 non-null   float64
#  32  tests_per_case                              71025 non-null   float64
#  33  tests_units                                 78690 non-null   object
#  34  total_vaccinations                          40679 non-null   float64
#  35  people_vaccinated                           38877 non-null   float64
#  36  people_fully_vaccinated                     35929 non-null   float64
#  37  total_boosters                              13491 non-null   float64
#  38  new_vaccinations                            33757 non-null   float64
#  39  new_vaccinations_smoothed                   74645 non-null   float64
#  40  total_vaccinations_per_hundred              40679 non-null   float64
#  41  people_vaccinated_per_hundred               38877 non-null   float64
#  42  people_fully_vaccinated_per_hundred         35929 non-null   float64
#  43  total_boosters_per_hundred                  13491 non-null   float64
#  44  new_vaccinations_smoothed_per_million       74645 non-null   float64
#  45  new_people_vaccinated_smoothed              73619 non-null   float64
#  46  new_people_vaccinated_smoothed_per_hundred  73619 non-null   float64
#  47  stringency_index                            122243 non-null  float64
#  48  population                                  154828 non-null  float64
#  49  population_density                          138742 non-null  float64
#  50  median_age                                  129317 non-null  float64
#  51  aged_65_older                               127913 non-null  float64
#  52  aged_70_older                               128623 non-null  float64
#  53  gdp_per_capita                              129903 non-null  float64
#  54  extreme_poverty                             85626 non-null   float64
#  55  cardiovasc_death_rate                       128309 non-null  float64
#  56  diabetes_prevalence                         135030 non-null  float64
#  57  female_smokers                              99516 non-null   float64
#  58  male_smokers                                98086 non-null   float64
#  59  handwashing_facilities                      64267 non-null   float64
#  60  hospital_beds_per_thousand                  116050 non-null  float64
#  61  life_expectancy                             145473 non-null  float64
#  62  human_development_index                     127784 non-null  float64
#  63  excess_mortality_cumulative_absolute        5338 non-null    float64
#  64  excess_mortality_cumulative                 5338 non-null    float64
#  65  excess_mortality                            5338 non-null    float64
#  66  excess_mortality_cumulative_per_million     5338 non-null    float64
# dtypes: float64(62), object(5)
# memory usage: 79.7+ MB

# %%
numerical_columns = []
categorical_columns = []
for column in data.columns:
    if data[column].dtype == float:
        numerical_columns.append(column)
    else:
        categorical_columns.append(column)

# %%
# Handling missing numerical values
imputer = IterativeImputer(max_iter = 1000, verbose=1)
data[numerical_columns] = pd.DataFrame(imputer.fit_transform(data[numerical_columns]), columns = numerical_columns)
# Out:
# [IterativeImputer] Completing matrix with shape (155858, 62)
# [IterativeImputer] Change: 5898430182.313889, scaled tolerance: 9788986.851
# [IterativeImputer] Change: 15257873.774624482, scaled tolerance: 9788986.851
# [IterativeImputer] Change: 200530.9712930398, scaled tolerance: 9788986.851
# [IterativeImputer] Early stopping criterion reached.

# %%
data[categorical_columns].isnull().sum()/len(data)
# Out:
# iso_code       0.000000
# continent      0.060125
# location       0.000000
# date           0.000000
# tests_units    0.495117
# dtype: float64

# %%
# Frequent category imputation
catimputer = fei.CategoricalImputer(imputation_method='frequent')
data[['continent']] = catimputer.fit_transform(data[['continent']])

# %%
# Missing category imputation
catimputer = fei.CategoricalImputer(imputation_method='missing', fill_value='Missing')
data[['tests_units']] = catimputer.fit_transform(data[['tests_units']])

# %%
# Checking for gaussian distribution of numerical variables using anderson test
gaussian_columns = []
non_gaussian_columns = []
for column in numerical_columns:
    result = st.anderson(data[column])
    if result[0] > result[1][2]:
        non_gaussian_columns.append(column)
    else:
        gaussian_columns.append(column)
print(f"List of gaussian variables: {gaussian_columns}")
print(f"List of non-gaussian variables: {non_gaussian_columns}")
# Out:
# List of gaussian variables: []
# List of non-gaussian variables: ['total_cases', 'new_cases', 'new_cases_smoothed', 'total_deaths', 'new_deaths', 'new_deaths_smoothed', 'total_cases_per_million', 'new_cases_per_million', 'new_cases_smoothed_per_million', 'total_deaths_per_million', 'new_deaths_per_million', 'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients', 'icu_patients_per_million', 'hosp_patients', 'hosp_patients_per_million', 'weekly_icu_admissions', 'weekly_icu_admissions_per_million', 'weekly_hosp_admissions', 'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'positive_rate', 'tests_per_case', 'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated', 'total_boosters', 'new_vaccinations', 'new_vaccinations_smoothed', 'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred', 'new_vaccinations_smoothed_per_million', 'new_people_vaccinated_smoothed', 'new_people_vaccinated_smoothed_per_hundred', 'stringency_index', 'population', 'population_density', 'median_age', 'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty', 'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers', 'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand', 'life_expectancy', 'human_development_index', 'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative', 'excess_mortality', 'excess_mortality_cumulative_per_million']

# %%
# Checking proportion of outliers
outlier_prop = []
for column in non_gaussian_columns:
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outlier_prop.append(np.round(len(data[(data[column] < lower_bound) | (data[column] > upper_bound)])/len(data),4))
results = pd.concat([pd.Series(data[non_gaussian_columns].columns),pd.Series(outlier_prop)],axis=1)\
            .rename({0:'Variable',1:'Prop_Outliers'},axis=1)
results.sort_values(by='Prop_Outliers',ascending=False).head(10)
# Out:
#                                 Variable  Prop_Outliers
# 28                        tests_per_case         0.2928
# 35        total_vaccinations_per_hundred         0.2518
# 37   people_fully_vaccinated_per_hundred         0.2432
# 36         people_vaccinated_per_hundred         0.2415
# 15                         hosp_patients         0.1991
# 1                              new_cases         0.1694
# 2                     new_cases_smoothed         0.1685
# 0                            total_cases         0.1645
# 58  excess_mortality_cumulative_absolute         0.1581
# 43                            population         0.1392

# %% [markdown]
# ## Capping outliers at extreme value bound (Winsorizer)

# %%
data_copy = data.copy()
for column in non_gaussian_columns:
    sns.catplot(data=data_copy, x=column, kind='box')
    plt.show()

# %%
# Capping extreme outliers using 3*IQR
winsorizer = feo.Winsorizer(capping_method='iqr', tail='both', fold=3, add_indicators=False)
data_copy[non_gaussian_columns] = winsorizer.fit_transform(data_copy[non_gaussian_columns])

# %%
for column in non_gaussian_columns:
    sns.catplot(data=data_copy, x=column, kind='box')
    plt.show()

# %% [markdown]
# ## Removing outliers (OutlierTrimmer)

# %%
data_copy = data.copy()
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155858 entries, 0 to 155857
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    155858 non-null  object
#  1   continent                                   155858 non-null  object
#  2   location                                    155858 non-null  object
#  3   date                                        155858 non-null  object
#  4   total_cases                                 155858 non-null  float64
#  5   new_cases                                   155858 non-null  float64
#  6   new_cases_smoothed                          155858 non-null  float64
#  7   total_deaths                                155858 non-null  float64
#  8   new_deaths                                  155858 non-null  float64
#  9   new_deaths_smoothed                         155858 non-null  float64
#  10  total_cases_per_million                     155858 non-null  float64
#  11  new_cases_per_million                       155858 non-null  float64
#  12  new_cases_smoothed_per_million              155858 non-null  float64
#  13  total_deaths_per_million                    155858 non-null  float64
#  14  new_deaths_per_million                      155858 non-null  float64
#  15  new_deaths_smoothed_per_million             155858 non-null  float64
#  16  reproduction_rate                           155858 non-null  float64
#  17  icu_patients                                155858 non-null  float64
#  18  icu_patients_per_million                    155858 non-null  float64
#  19  hosp_patients                               155858 non-null  float64
#  20  hosp_patients_per_million                   155858 non-null  float64
#  21  weekly_icu_admissions                       155858 non-null  float64
#  22  weekly_icu_admissions_per_million           155858 non-null  float64
#  23  weekly_hosp_admissions                      155858 non-null  float64
#  24  weekly_hosp_admissions_per_million          155858 non-null  float64
#  25  new_tests                                   155858 non-null  float64
#  26  total_tests                                 155858 non-null  float64
#  27  total_tests_per_thousand                    155858 non-null  float64
#  28  new_tests_per_thousand                      155858 non-null  float64
#  29  new_tests_smoothed                          155858 non-null  float64
#  30  new_tests_smoothed_per_thousand             155858 non-null  float64
#  31  positive_rate                               155858 non-null  float64
#  32  tests_per_case                              155858 non-null  float64
#  33  tests_units                                 155858 non-null  object
#  34  total_vaccinations                          155858 non-null  float64
#  35  people_vaccinated                           155858 non-null  float64
#  36  people_fully_vaccinated                     155858 non-null  float64
#  37  total_boosters                              155858 non-null  float64
#  38  new_vaccinations                            155858 non-null  float64
#  39  new_vaccinations_smoothed                   155858 non-null  float64
#  40  total_vaccinations_per_hundred              155858 non-null  float64
#  41  people_vaccinated_per_hundred               155858 non-null  float64
#  42  people_fully_vaccinated_per_hundred         155858 non-null  float64
#  43  total_boosters_per_hundred                  155858 non-null  float64
#  44  new_vaccinations_smoothed_per_million       155858 non-null  float64
#  45  new_people_vaccinated_smoothed              155858 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  155858 non-null  float64
#  47  stringency_index                            155858 non-null  float64
#  48  population                                  155858 non-null  float64
#  49  population_density                          155858 non-null  float64
#  50  median_age                                  155858 non-null  float64
#  51  aged_65_older                               155858 non-null  float64
#  52  aged_70_older                               155858 non-null  float64
#  53  gdp_per_capita                              155858 non-null  float64
#  54  extreme_poverty                             155858 non-null  float64
#  55  cardiovasc_death_rate                       155858 non-null  float64
#  56  diabetes_prevalence                         155858 non-null  float64
#  57  female_smokers                              155858 non-null  float64
#  58  male_smokers                                155858 non-null  float64
#  59  handwashing_facilities                      155858 non-null  float64
#  60  hospital_beds_per_thousand                  155858 non-null  float64
#  61  life_expectancy                             155858 non-null  float64
#  62  human_development_index                     155858 non-null  float64
#  63  excess_mortality_cumulative_absolute        155858 non-null  float64
#  64  excess_mortality_cumulative                 155858 non-null  float64
#  65  excess_mortality                            155858 non-null  float64
#  66  excess_mortality_cumulative_per_million     155858 non-null  float64
# dtypes: float64(62), object(5)
# memory usage: 79.7+ MB

# %%
# Removing outliers using 1.5*IQR
trimmer = feo.OutlierTrimmer(capping_method='iqr', tail='both', fold=1.5)
data_copy[non_gaussian_columns] = trimmer.fit_transform(data_copy[non_gaussian_columns])

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155858 entries, 0 to 155857
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    155858 non-null  object
#  1   continent                                   155858 non-null  object
#  2   location                                    155858 non-null  object
#  3   date                                        155858 non-null  object
#  4   total_cases                                 21721 non-null   float64
#  5   new_cases                                   21721 non-null   float64
#  6   new_cases_smoothed                          21721 non-null   float64
#  7   total_deaths                                21721 non-null   float64
#  8   new_deaths                                  21721 non-null   float64
#  9   new_deaths_smoothed                         21721 non-null   float64
#  10  total_cases_per_million                     21721 non-null   float64
#  11  new_cases_per_million                       21721 non-null   float64
#  12  new_cases_smoothed_per_million              21721 non-null   float64
#  13  total_deaths_per_million                    21721 non-null   float64
#  14  new_deaths_per_million                      21721 non-null   float64
#  15  new_deaths_smoothed_per_million             21721 non-null   float64
#  16  reproduction_rate                           21721 non-null   float64
#  17  icu_patients                                21721 non-null   float64
#  18  icu_patients_per_million                    21721 non-null   float64
#  19  hosp_patients                               21721 non-null   float64
#  20  hosp_patients_per_million                   21721 non-null   float64
#  21  weekly_icu_admissions                       21721 non-null   float64
#  22  weekly_icu_admissions_per_million           21721 non-null   float64
#  23  weekly_hosp_admissions                      21721 non-null   float64
#  24  weekly_hosp_admissions_per_million          21721 non-null   float64
#  25  new_tests                                   21721 non-null   float64
#  26  total_tests                                 21721 non-null   float64
#  27  total_tests_per_thousand                    21721 non-null   float64
#  28  new_tests_per_thousand                      21721 non-null   float64
#  29  new_tests_smoothed                          21721 non-null   float64
#  30  new_tests_smoothed_per_thousand             21721 non-null   float64
#  31  positive_rate                               21721 non-null   float64
#  32  tests_per_case                              21721 non-null   float64
#  33  tests_units                                 155858 non-null  object
#  34  total_vaccinations                          21721 non-null   float64
#  35  people_vaccinated                           21721 non-null   float64
#  36  people_fully_vaccinated                     21721 non-null   float64
#  37  total_boosters                              21721 non-null   float64
#  38  new_vaccinations                            21721 non-null   float64
#  39  new_vaccinations_smoothed                   21721 non-null   float64
#  40  total_vaccinations_per_hundred              21721 non-null   float64
#  41  people_vaccinated_per_hundred               21721 non-null   float64
#  42  people_fully_vaccinated_per_hundred         21721 non-null   float64
#  43  total_boosters_per_hundred                  21721 non-null   float64
#  44  new_vaccinations_smoothed_per_million       21721 non-null   float64
#  45  new_people_vaccinated_smoothed              21721 non-null   float64
#  46  new_people_vaccinated_smoothed_per_hundred  21721 non-null   float64
#  47  stringency_index                            21721 non-null   float64
#  48  population                                  21721 non-null   float64
#  49  population_density                          21721 non-null   float64
#  50  median_age                                  21721 non-null   float64
#  51  aged_65_older                               21721 non-null   float64
#  52  aged_70_older                               21721 non-null   float64
#  53  gdp_per_capita                              21721 non-null   float64
#  54  extreme_poverty                             21721 non-null   float64
#  55  cardiovasc_death_rate                       21721 non-null   float64
#  56  diabetes_prevalence                         21721 non-null   float64
#  57  female_smokers                              21721 non-null   float64
#  58  male_smokers                                21721 non-null   float64
#  59  handwashing_facilities                      21721 non-null   float64
#  60  hospital_beds_per_thousand                  21721 non-null   float64
#  61  life_expectancy                             21721 non-null   float64
#  62  human_development_index                     21721 non-null   float64
#  63  excess_mortality_cumulative_absolute        21721 non-null   float64
#  64  excess_mortality_cumulative                 21721 non-null   float64
#  65  excess_mortality                            21721 non-null   float64
#  66  excess_mortality_cumulative_per_million     21721 non-null   float64
# dtypes: float64(62), object(5)
# memory usage: 79.7+ MB

# %%
for column in non_gaussian_columns:
    sns.catplot(data=data_copy, x=column, kind='box')
    plt.show()

# %% [markdown]
# Note that after initial outlier removal, outliers can still exist due to changes in quantile values or original variable distribution is very heavily skewed.

# %% [markdown]
# ## Machine Learning Algorithms Sensitive to Outliers
#
# While some machine learning algorithms are not sensitive to outliers, there are some ML algorithms that are sensitive to outliers:
#
# 1. Linear Regression
# 2. Logistic Regression
# 3. KNN
# 4. Kmeans Clustering
# 5. Hierarchical Clustering
# 6. Neural Networks
# 7. PCA
#
# More details about why these algorithms are sensitive to outliers would be covered in Machine Learning section.
